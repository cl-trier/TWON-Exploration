# %%
import pandas as pd

from sklearn.metrics import cohen_kappa_score, classification_report
import krippendorff
import numpy as np

# %%
data = pd.read_parquet("data/publicsphere/publicsphere.cardiff_prompt_classify_anon.parquet")
data.head()
# Out:
#              StartDate         RecordedDate        IPAddress  Finished  Coder  \
# 0   5/30/2021 13:03:17   5/30/2021 13:04:17     62.194.51.29         1      6
# 1  10/11/2021 10:34:05  10/11/2021 10:36:46  213.127.109.191         1      6
# 2    9/9/2021 18:49:48    9/9/2021 18:51:32    213.127.110.0         1      6
# 3    6/6/2021 16:12:46    6/6/2021 16:16:16   213.127.76.145         1      6
# 4   6/13/2021 13:25:49   6/13/2021 13:27:28   213.127.82.232         1      6
#
#                                                   ID  Mark_ID  Genre  \
# 0  UgyPHwv8G0cDE6-wEgl4AaABAg.8_0ZjJKSJty8_0kXGkAd2U      119      0
# 1  Ugx2WXq9UdV8mPPjejJ4AaABAg.8yHCKV0Boe58yYRxEQEF45      282      1
# 2                                1110578710648890000      372      2
# 3  UgwUPFScjJ0MCeaP2F54AaABAg.8lvp3fc9Euf8lvvgsUgEgV      769      0
# 4  UgwWKCWtSJdFvjGHvTp4AaABAg.8kUC5dGrQ2H8kUDRihE2f3     1206      0
#
#    topiccode  Platform  ...  rationality_topic_relevance  \
# 0          0         1  ...                           No
# 1          2         1  ...                          Yes
# 2          4         2  ...                          Yes
# 3          0         1  ...                          Yes
# 4          0         1  ...                           No
#
#      political_negativity  rationality_background_info  rationality_reasoning  \
# 0  not political/negative                           No                     No
# 1  not political/negative                           No                    Yes
# 2      political/negative                           No                     No
# 3      political/negative                          Yes                    Yes
# 4  not political/negative                           No                     No
#
#              sentiment                       offensive  \
# 0  [negative, neutral]  {'offensive', 'non-offensive'}
# 1  [negative, neutral]  {'offensive', 'non-offensive'}
# 2  [negative, neutral]               {'non-offensive'}
# 3  [negative, neutral]               {'non-offensive'}
# 4  [positive, neutral]               {'non-offensive'}
#
#                       topics                              emotions  \
# 0                      set()              {'sadness', 'pessimism'}
# 1  {'news_&_social_concern'}                  {'disgust', 'anger'}
# 2  {'news_&_social_concern'}  {'anticipation', 'disgust', 'anger'}
# 3  {'news_&_social_concern'}                           {'disgust'}
# 4   {'diaries_&_daily_life'}                           {'sadness'}
#
#                     irony          hate
# 0  {'non_irony', 'irony'}  {'NOT-HATE'}
# 1           {'non_irony'}  {'NOT-HATE'}
# 2           {'non_irony'}  {'NOT-HATE'}
# 3               {'irony'}  {'NOT-HATE'}
# 4  {'non_irony', 'irony'}  {'NOT-HATE'}
#
# [5 rows x 91 columns]

# %%
llm_human_column_pairs = [
    ("Acknowledgement", "interactivity_acknowledgement"),
    ("BackgroundInfo", "rationality_background_info"),
    ("ExternalEvidence", "rationality_external_evidence"),
    ("Reasoning", "rationality_reasoning"),
    ("TopicRelevance", "rationality_topic_relevance"),
]

# %%
print("Inter-coder reliablity: classification_report(human as gold, llm as predicted), cohen_kappa(human, llm):")

for human_col, llm_col in llm_human_column_pairs:
    subset = data[[human_col, llm_col]].dropna()
    human = subset[human_col].map({0: "No", 1: "Yes"}).tolist()
    llm = subset[llm_col].tolist()
    
    print("---")
    print(f"{classification_report(human, llm)}")
    print(f"cohen_kappa_score({human_col}): {cohen_kappa_score(human, llm)}")
    print(f"krippendorf({human_col}): {krippendorff.alpha(np.array([human, llm]), level_of_measurement="nominal")}")
# Out:
# Inter-coder reliablity: classification_report(human as gold, llm as predicted), cohen_kappa(human, llm):
# ---
#               precision    recall  f1-score   support
#
#           No       0.83      0.74      0.78      2854
#          Yes       0.44      0.58      0.50      1004
#
#     accuracy                           0.70      3858
#    macro avg       0.64      0.66      0.64      3858
# weighted avg       0.73      0.70      0.71      3858
#
# cohen_kappa_score(Acknowledgement): 0.2889861702288804
# krippendorf(Acknowledgement): 0.2829925650557621
# ---
#               precision    recall  f1-score   support
#
#           No       0.96      0.87      0.92      3469
#          Yes       0.38      0.68      0.49       389
#
#     accuracy                           0.86      3858
#    macro avg       0.67      0.78      0.70      3858
# weighted avg       0.90      0.86      0.87      3858
#
# cohen_kappa_score(BackgroundInfo): 0.41023725361398966
# krippendorf(BackgroundInfo): 0.4024105964926574
# ---
#               precision    recall  f1-score   support
#
#           No       1.00      0.86      0.92      3756
#          Yes       0.13      0.83      0.23        95
#
#     accuracy                           0.86      3851
#    macro avg       0.56      0.85      0.58      3851
# weighted avg       0.97      0.86      0.91      3851
#
# cohen_kappa_score(ExternalEvidence): 0.19296336116482482
# krippendorf(ExternalEvidence): 0.15081075142740097
# ---
#               precision    recall  f1-score   support
#
#           No       0.97      0.63      0.76      3513
#          Yes       0.17      0.80      0.29       343
#
#     accuracy                           0.64      3856
#    macro avg       0.57      0.72      0.53      3856
# weighted avg       0.90      0.64      0.72      3856
#
# cohen_kappa_score(Reasoning): 0.16454212120291312
# krippendorf(Reasoning): 0.05041105925850564
# ---
#               precision    recall  f1-score   support
#
#           No       0.84      0.70      0.76      1550
#          Yes       0.82      0.91      0.86      2308
#
#     accuracy                           0.83      3858
#    macro avg       0.83      0.81      0.81      3858
# weighted avg       0.83      0.83      0.82      3858
#
# cohen_kappa_score(TopicRelevance): 0.6284620730257044
# krippendorf(TopicRelevance): 0.6268766660042833
