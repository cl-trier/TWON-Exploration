# %%
import typing

import pandas as pd
import numpy as np

import src
import config

# %%
CFG = config.Config()

# %%
dataset: pd.DataFrame = pd.read_parquet(CFG.final_data_files["user_content"])
dataset
# Out:
#                                             postId  \
# id
# 66261d9883ad1b524033b95f  66226af08c2024fabb3cc44c
# 66261fac83ad1b524033b9b7  662296c6616a4cb7061eaae7
# 66261cda83ad1b524033b93b  6622a4d5616a4cb7061ead43
# 66261f0c83ad1b524033b993  6622a983616a4cb7061eae17
# 6626211283ad1b524033b9f2  6622bc44616a4cb7061eb0f2
# ...                                            ...
# 662a070537d6395f42ca7bfd                      None
# 662a12fa37d6395f42ca87fe                      None
# 662a30f137d6395f42ca99c6                      None
# 662e892b3ae8346ce92c8e85                      None
# 662f64083ae8346ce92c9d25                      None
#
#                                                                     content  \
# id
# 66261d9883ad1b524033b95f  Gut gesagt! Vergesst nicht, dass auch wirtscha...
# 66261fac83ad1b524033b9b7  Richtig gesagt, @Gelber Roboter! Eine ausgewog...
# 66261cda83ad1b524033b93b  @Gelber Roboter, @Blaues Siegel, @Weißer Hase,...
# ...

# %%
embeds: typing.Dict[str, np.ndarray] = (
    pd.Series(src.SentenceEmbedder()(dataset["content"]), name="embeds")
    .rename_axis(index=dataset.index.names)
)
embeds
# Out:
#  63%|██████▎   | 1229/1953 [02:26<01:27,  8.24it/s]

# %%
dataset_w_embeds = dataset.join(embeds).dropna()
dataset_w_embeds.to_parquet(f'{CFG.report_dir}/dataset.embeds.parquet')
dataset_w_embeds.head()
# Out:
#                                             postId  \
# id
# 662bf0253ae8346ce92c36c0  6626a4a9f62e42fb4c5c6a82
# 66261a0983ad1b524033b8c6  6626119d83ad1b524033b77e
# 6627bf65a6b56b19b430056a  66278973f62e42fb4c5cb1fd
# 66268fd6d4ec55a25b931399  66268e22f62e42fb4c5c4a3c
# 66309e3a889820447de1f7cd  662d54cb889820447de1a0bc
#
#                                                                     content  \
# id
# 662bf0253ae8346ce92c36c0                               April, April .... :D
# 66261a0983ad1b524033b8c6  Gute Perspektive! Konfliktlösung durch Dialog ...
# 6627bf65a6b56b19b430056a  @Weißer Igel, interessante Leere. Manchmal sag...
# 66268fd6d4ec55a25b931399  @LilaSchwan Danke für die Info! Es ist wichtig...
# 66309e3a889820447de1f7cd  Ganz meiner Meinung, @Blauer Biber! Diplomatie...
#
#                                             userId                createdAt  \
# id
# 662bf0253ae8346ce92c36c0  66279e2b223c875b6385b317  2024-04-26 18:19:17.910
# ...

# %%
groups = {
    "humans": dataset_w_embeds[dataset_w_embeds["userType"] == "human"]["embeds"],
    "bots": dataset_w_embeds[dataset_w_embeds["userType"] == "bot"]["embeds"]
}

# %%
distances = (
    pd.Series(src.DistanceMetric()(groups), name="distance")
    .rename_axis(index=("Group 1", "Group 2"))
    .reset_index()
    .pivot(index='Group 1', columns='Group 2', values='distance')
)
distances
# Out:
# Group 2       bots     humans
# Group 1
# bots     13.285615        NaN
# humans   17.930746  12.849591
